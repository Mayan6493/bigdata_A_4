# %% [markdown]
# ## Mayan Bhut
# ## 202318043

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=df0292b967ada263f07a5c22993a382ffc27fefaa8549d908cd61fb278139fd7
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 79, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     with self.main_context():
#   File "/usr/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/command_context.py", line 19, in main_context
#     with self._main_context:
#   File "/usr/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/usr/lib/python3.10/contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/temp_dir.py", line 70, in tempdir_registry
#     yield _tempdir_registry
#   File "/usr/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/usr/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/temp_dir.py", line 31, in global_tempdir_manager
#     with ExitStack() as stack:
#   File "/usr/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/usr/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/temp_dir.py", line 156, in __exit__
#     self.cleanup()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/temp_dir.py", line 173, in cleanup
#     rmtree(self._path)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/tenacity/__init__.py", line 291, in wrapped_f
#     return self(f, *args, **kw)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/tenacity/__init__.py", line 381, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/tenacity/__init__.py", line 316, in iter
#     return fut.result()
#   File "/usr/lib/python3.10/concurrent/futures/_base.py", line 451, in result
#     return self.__get_result()
#   File "/usr/lib/python3.10/concurrent/futures/_base.py", line 403, in __get_result
#     raise self._exception
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/tenacity/__init__.py", line 384, in __call__
#     result = fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/misc.py", line 130, in rmtree
#     shutil.rmtree(dir, ignore_errors=ignore_errors, onerror=rmtree_errorhandler)
#   File "/usr/lib/python3.10/shutil.py", line 725, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/usr/lib/python3.10/shutil.py", line 679, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# KeyboardInterrupt
# ^C

# %% [markdown]
# **(1)For RDD task 2 you will be using the following text data.**

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("RDD and DataFrame Manipulation") \
    .getOrCreate()

# %%
rdd = spark.sparkContext.textFile("/content/text8")

# %%
type(rdd)
# Out:
# pyspark.rdd.RDD

# %%
import numpy as np

# %% [markdown]
# **RDD Tasks
# – TASK-1: Generate 100 random numbers in range 0 to 10 using numpy
# randint function with the seed set to 10. Create a RDD using the paral-
# lelize function using data generated in previous step. Calculate the fre-
# quency of each number (0 - 10) using appropriate function of RDD.**

# %%
from pyspark.sql import SparkSession


# Create a SparkSession
spark = SparkSession.builder \
    .appName("RDD Task 1") \
    .getOrCreate()

# Generate 100 random numbers in the range 0 to 10 using numpy
np.random.seed(10)  # Set seed for reproducibility
random_numbers = np.random.randint(0, 11, size=100)
print(random_numbers)

# Create an RDD using the parallelize function
rdd = spark.sparkContext.parallelize(random_numbers)

# Calculate the frequency of each number (0 - 10) using appropriate function of RDD
frequency_counts = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortByKey()

# Collect the results
results = frequency_counts.collect()

# Print the results
print("Number\tFrequency")
for number, frequency in results:
    print(f"{number}\t{frequency}")

# Stop the SparkSession
spark.stop()
# Out:
# [ 9  4  0  1  9  0  1 10  8  9  0 10  8  6  4  3  0  4  6  8 10  1  8  4
#   1  3  6  5  3  9  6  9  1  9  4  2  6  7  8 10  8  9  2  0  6  7  8  1
#   7  1  4 10  0  8  5  4  7  8  8  2  6  2  8  8  6  6  5 10  6  0  0  6
#   9  1  8 10  9  1  2  8  9  9  5  0  2  7  3  0  4  2  0  3  3  1  2  5
#   9  0 10  1]
# Number	Frequency
# 0	12
# 1	11
# 2	8
# 3	6
# 4	8
# 5	5
# 6	11
# 7	5
# 8	14
# 9	12
# 10	8

# %% [markdown]
# **TASK-2: In this task you will calculate the frequency of each word in
# text8 dataset mentioned above. Create a RDD using the text8 dataset.Use appropriate functions of the RDD to get the word frequencies. Fil-
# ter the RDD using appropriate function to get the frequencies of words containing the letter ’a’**

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("RDD Task 2") \
    .getOrCreate()

# Create an RDD using the text8 dataset
text_rdd = spark.sparkContext.textFile("/content/text8.unknown")

# Split each line into words and flatten the list of words
words_rdd = text_rdd.flatMap(lambda line: line.split())

# Calculate the frequency of each word
word_frequencies = words_rdd.map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)

# Filter the RDD to get the frequencies of words containing the letter 'a'
words_with_a_frequencies = word_frequencies.filter(lambda pair: 'a' in pair[0])

# Collect and print the results
results = words_with_a_frequencies.collect()
for word, frequency in results:
    print(f"Word: {word}\tFrequency: {frequency}")

# Stop the SparkSession
spark.stop()
# Out:
# Streaming output truncated to the last 5000 lines.
# Word: contaminated	Frequency: 2
# Word: addicts	Frequency: 5
# Word: prophylaxis	Frequency: 1
# Word: bleach	Frequency: 2
# Word: decriminalized	Frequency: 1
# Word: pharmacists	Frequency: 1
# Word: transcriptase	Frequency: 2
# Word: spans	Frequency: 1
# Word: rapidity	Frequency: 2
# Word: pneumoniae	Frequency: 1
# Word: prophylactic	Frequency: 2
# Word: atys	Frequency: 1
# Word: inadvertantly	Frequency: 1
# Word: hilary	Frequency: 4
# Word: pandemic	Frequency: 1
# Word: aidsmeds	Frequency: 1
# Word: fightaids	Frequency: 1
# Word: scenarios	Frequency: 3
# Word: reappraisal	Frequency: 1
# Word: denialism	Frequency: 1
# Word: aidsorigin	Frequency: 1
# Word: anni	Frequency: 4
# Word: lyngstad	Frequency: 2
# Word: frida	Frequency: 12
# Word: hootenanny	Frequency: 3
# Word: lycka	Frequency: 2
# Word: folkpark	Frequency: 2
# Word: sedaka	Frequency: 1
# Word: canning	Frequency: 2
# Word: canners	Frequency: 2
# Word: mamma	Frequency: 8
# Word: wizzard	Frequency: 1
# Word: unashamedly	Frequency: 1
# Word: catchy	Frequency: 3
# Word: straightaway	Frequency: 1
# Word: hubristically	Frequency: 1
# Word: ensam	Frequency: 1
# Word: validated	Frequency: 3
# Word: standalone	Frequency: 1
# Word: chiquitita	Frequency: 3
# Word: gracias	Frequency: 1
# Word: musica	Frequency: 1
# Word: maturity	Frequency: 5
# Word: collaborated	Frequency: 4
# Word: bangkok	Frequency: 2
# Word: kristina	Frequency: 2
# Word: tetralogy	Frequency: 1
# Word: svenska	Frequency: 3
# Word: artistes	Frequency: 1
# Word: blancmange	Frequency: 1
# Word: satisfy	Frequency: 12
# Word: gala	Frequency: 1
# Word: wrap	Frequency: 1
# Word: chocolat	Frequency: 1
# Word: coogan	Frequency: 1
# Word: saunders	Frequency: 1
# Word: notate	Frequency: 1
# Word: cavett	Frequency: 1
# Word: embargo	Frequency: 4
# Word: priscilla	Frequency: 3
# Word: rowan	Frequency: 2
# Word: sampled	Frequency: 2
# Word: gayle	Frequency: 1
# Word: vocalhalloffame	Frequency: 1
# Word: abbamail	Frequency: 1
# Word: ligeantia	Frequency: 6
# Word: patriam	Frequency: 1
# Word: naturalization	Frequency: 4
# Word: affords	Frequency: 2
# Word: ligamen	Frequency: 2
# Word: isaacson	Frequency: 3
# Word: boast	Frequency: 1
# Word: allegiances	Frequency: 1
# Word: gavin	Frequency: 1
# Word: sattler	Frequency: 1
# Word: dears	Frequency: 1
# Word: naturalis	Frequency: 1
# Word: absoluta	Frequency: 1
# Word: alta	Frequency: 1
# Word: natus	Frequency: 1
# Word: acquisita	Frequency: 1
# Word: datus	Frequency: 1
# Word: localis	Frequency: 1
# Word: app	Frequency: 3
# Word: parl	Frequency: 1
# Word: limitation	Frequency: 3
# Word: restraint	Frequency: 2
# Word: angelique	Frequency: 1
# Word: geneneral	Frequency: 1
# Word: voluntarily	Frequency: 4
# Word: parentage	Frequency: 2
# Word: preamble	Frequency: 2
# Word: expatriation	Frequency: 2
# Word: indispensable	Frequency: 1
# Word: supermajoritarian	Frequency: 1
# Word: grandmaster	Frequency: 5
# Word: alexis	Frequency: 14
# Word: colossal	Frequency: 1
# Word: mainframe	Frequency: 1
# Word: adventureland	Frequency: 2
# Word: buckaroo	Frequency: 2
# Word: altenberg	Frequency: 5
# Word: montagne	Frequency: 1
# Word: ceratopsian	Frequency: 1
# Word: serendipaceratops	Frequency: 1
# Word: tsunamis	Frequency: 1
# Word: taunton	Frequency: 1
# Word: accelerates	Frequency: 2
# Word: paedophilia	Frequency: 1
# Word: carol	Frequency: 2
# Word: braun	Frequency: 5
# Word: speculations	Frequency: 4
# Word: extrapolation	Frequency: 4
# Word: mainstays	Frequency: 2
# Word: salted	Frequency: 1
# Word: downplay	Frequency: 1
# Word: hyams	Frequency: 3
# Word: revelations	Frequency: 3
# Word: clarketech	Frequency: 1
# Word: acc	Frequency: 2
# Word: arthurcclarke	Frequency: 1
# Word: messagepad	Frequency: 19
# Word: residential	Frequency: 2
# Word: abandonware	Frequency: 1
# Word: notepad	Frequency: 1
# Word: drawer	Frequency: 1
# Word: trapezoidal	Frequency: 1
# Word: adapter	Frequency: 1
# Word: pcmcia	Frequency: 1
# Word: handset	Frequency: 2
# Word: fax	Frequency: 3
# Word: clearer	Frequency: 1
# Word: plaudits	Frequency: 1
# Word: palmos	Frequency: 1
# Word: replaceable	Frequency: 2
# Word: unsurpassed	Frequency: 1
# Word: slogan	Frequency: 1
# Word: pdas	Frequency: 5
# Word: donna	Frequency: 1
# Word: calligrapher	Frequency: 1
# Word: formulas	Frequency: 14
# Word: tap	Frequency: 1
# Word: tablets	Frequency: 3
# Word: retracting	Frequency: 1
# Word: upgrade	Frequency: 1
# Word: strongarm	Frequency: 1
# Word: seagal	Frequency: 1
# Word: kate	Frequency: 5
# Word: hacker	Frequency: 3
# Word: trudeau	Frequency: 1
# Word: daulph	Frequency: 2
# Word: petronas	Frequency: 2
# Word: petrosains	Frequency: 2
# Word: callan	Frequency: 1
# Word: gateways	Frequency: 1
# Word: yaeger	Frequency: 2
# Word: newtonsearch	Frequency: 1
# Word: newtonrepair	Frequency: 1
# Word: emulator	Frequency: 1
# Word: attemps	Frequency: 1
# Word: carnivorous	Frequency: 4
# Word: patched	Frequency: 1
# Word: slan	Frequency: 2
# Word: nexialism	Frequency: 1
# Word: overarching	Frequency: 2
# Word: ptath	Frequency: 2
# Word: dianetics	Frequency: 1
# Word: harassed	Frequency: 1
# Word: lydia	Frequency: 2
# Word: edna	Frequency: 6
# Word: mayne	Frequency: 4
# Word: transfinite	Frequency: 2
# Word: marvels	Frequency: 2
# Word: triangulum	Frequency: 1
# Word: galaxy	Frequency: 8
# Word: moonbeast	Frequency: 1
# Word: diamondia	Frequency: 1
# Word: scifan	Frequency: 1
# Word: startling	Frequency: 1
# Word: fansite	Frequency: 2
# Word: blazed	Frequency: 1
# Word: arpawocky	Frequency: 2
# Word: pastiche	Frequency: 2
# Word: legalese	Frequency: 1
# Word: gigabit	Frequency: 1
# Word: chapin	Frequency: 1
# Word: atm	Frequency: 1
# Word: ashworth	Frequency: 1
# Word: ramos	Frequency: 1
# Word: masinter	Frequency: 1
# Word: slavitch	Frequency: 1
# Word: glassman	Frequency: 1
# Word: manasse	Frequency: 1
# Word: bradner	Frequency: 3
# Word: rajagopalan	Frequency: 1
# Word: exical	Frequency: 1
# Word: drafts	Frequency: 1
# Word: kournikova	Frequency: 19
# Word: nna	Frequency: 1
# Word: rnikova	Frequency: 1
# Word: curtailed	Frequency: 2
# Word: martina	Frequency: 5
# Word: wta	Frequency: 2
# Word: serena	Frequency: 2
# Word: beachbreakers	Frequency: 1
# Word: carrey	Frequency: 1
# Word: alper	Frequency: 1
# Word: connotations	Frequency: 10
# Word: aseb	Frequency: 1
# Word: drachmann	Frequency: 2
# Word: atheonism	Frequency: 1
# Word: athean	Frequency: 1
# Word: atheal	Frequency: 1
# Word: antony	Frequency: 24
# Word: drange	Frequency: 1
# Word: pantheism	Frequency: 8
# Word: holbach	Frequency: 4
# Word: disagrees	Frequency: 2
# Word: atheous	Frequency: 1
# Word: tripartite	Frequency: 1
# Word: contemplative	Frequency: 2
# Word: morals	Frequency: 4
# Word: maritain	Frequency: 4
# Word: colonisation	Frequency: 2
# Word: vainglorious	Frequency: 1
# Word: rashly	Frequency: 1
# Word: evading	Frequency: 2
# Word: arising	Frequency: 6
# Word: abusive	Frequency: 2
# Word: mynga	Frequency: 1
# Word: gaskin	Frequency: 2
# Word: holyoake	Frequency: 1
# Word: apologist	Frequency: 2
# Word: assenting	Frequency: 1
# Word: apatheism	Frequency: 6
# Word: unpersuasive	Frequency: 1
# Word: ayer	Frequency: 8
# Word: nonsensical	Frequency: 3
# Word: transcendent	Frequency: 6
# Word: theological	Frequency: 36
# Word: falsifiability	Frequency: 1
# Word: technicalities	Frequency: 1
# Word: insofar	Frequency: 6
# Word: naturalism	Frequency: 7
# Word: baggini	Frequency: 5
# Word: supernaturalism	Frequency: 1
# Word: hyphenated	Frequency: 2
# Word: antitheist	Frequency: 1
# Word: antitheists	Frequency: 2
# Word: unpatriotic	Frequency: 1
# Word: leuba	Frequency: 1
# Word: clause	Frequency: 4
# Word: clauses	Frequency: 1
# Word: usable	Frequency: 2
# Word: inadequately	Frequency: 1
# Word: deviance	Frequency: 1
# Word: affilated	Frequency: 1
# Word: unintentionally	Frequency: 1
# Word: categorical	Frequency: 3
# Word: antithetical	Frequency: 1
# Word: thomasine	Frequency: 1
# Word: pantheists	Frequency: 1
# Word: brianism	Frequency: 1
# Word: universalism	Frequency: 3
# Word: idolatry	Frequency: 2
# Word: theologian	Frequency: 20
# Word: rabbis	Frequency: 7
# Word: psalm	Frequency: 3
# Word: hath	Frequency: 5
# Word: realists	Frequency: 1
# Word: lyas	Frequency: 2
# Word: irreconcilable	Frequency: 1
# Word: earnestness	Frequency: 1
# Word: ilhad	Frequency: 1
# Word: apostasy	Frequency: 10
# Word: imperatives	Frequency: 1
# Word: amitabha	Frequency: 1
# Word: adibuddha	Frequency: 1
# Word: tangible	Frequency: 3
# Word: confucianism	Frequency: 3
# Word: creationists	Frequency: 1
# Word: characterizing	Frequency: 1
# Word: malicious	Frequency: 1
# Word: normalization	Frequency: 1
# Word: hairs	Frequency: 2
# Word: fleas	Frequency: 1
# Word: pascal	Frequency: 5
# Word: wager	Frequency: 2
# Word: booktalk	Frequency: 1
# Word: eudaimonist	Frequency: 1
# Word: exchristian	Frequency: 1
# Word: messiah	Frequency: 5
# Word: therapist	Frequency: 2
# Word: religioustolerance	Frequency: 1
# Word: abstractatom	Frequency: 1
# Word: polemical	Frequency: 5
# Word: opiate	Frequency: 3
# Word: mcgrath	Frequency: 3
# Word: atheisme	Frequency: 1
# Word: arth	Frequency: 1
# Word: mornay	Frequency: 1
# Word: contrarian	Frequency: 1
# Word: mackie	Frequency: 1
# Word: mctaggart	Frequency: 4
# Word: pap	Frequency: 1
# Word: ana	Frequency: 2
# Word: sharpe	Frequency: 1
# Word: fatherless	Frequency: 1
# Word: dallas	Frequency: 2
# Word: chaff	Frequency: 1
# Word: noumena	Frequency: 1
# Word: scintilla	Frequency: 1
# Word: antithetic	Frequency: 1
# Word: intolerance	Frequency: 3
# Word: lays	Frequency: 2
# Word: olympians	Frequency: 1
# Word: utterances	Frequency: 1
# Word: agnosis	Frequency: 1
# Word: clathrates	Frequency: 1
# Word: germanium	Frequency: 2
# Word: scuba	Frequency: 3
# Word: inflate	Frequency: 2
# Word: rayleigh	Frequency: 1
# Word: ramsay	Frequency: 2
# Word: fractionation	Frequency: 1
# Word: acs	Frequency: 1
# Word: alamos	Frequency: 7
# Word: metalloid	Frequency: 3
# Word: gravities	Frequency: 1
# Word: sprayers	Frequency: 1
# Word: msma	Frequency: 1
# Word: tablespoon	Frequency: 1
# Word: arsphenamine	Frequency: 2
# Word: neosalvarsan	Frequency: 1
# Word: atra	Frequency: 1
# Word: gallium	Frequency: 2
# Word: arsenide	Frequency: 3
# Word: bandgap	Frequency: 1
# Word: infestations	Frequency: 1
# Word: arsenikon	Frequency: 1
# Word: arsenicthe	Frequency: 1
# Word: instigated	Frequency: 4
# Word: arsenopyrite	Frequency: 1
# Word: realgar	Frequency: 1
# Word: cobalt	Frequency: 1
# Word: pyrophosphate	Frequency: 1
# Word: haemorrhage	Frequency: 1
# Word: carcinogens	Frequency: 2
# Word: vittata	Frequency: 1
# Word: arsenicosis	Frequency: 1
# Word: aso	Frequency: 2
# Word: arsenous	Frequency: 1
# Word: arsine	Frequency: 1
# Word: pollutant	Frequency: 3
# Word: toxicological	Frequency: 2
# Word: contaminant	Frequency: 1
# Word: epa	Frequency: 1
# Word: metalloids	Frequency: 2
# Word: chalcophile	Frequency: 1
# Word: hardener	Frequency: 1
# Word: antifriction	Frequency: 1
# Word: tracer	Frequency: 1
# Word: retardant	Frequency: 2
# Word: antos	Frequency: 1
# Word: thiomalate	Frequency: 1
# Word: ruminants	Frequency: 2
# Word: antimonials	Frequency: 1
# Word: granules	Frequency: 1
# Word: cake	Frequency: 5
# Word: tal	Frequency: 4
# Word: minerais	Frequency: 1
# Word: gram	Frequency: 6
# Word: lanthanum	Frequency: 1
# Word: aktinos	Frequency: 1
# Word: radioisotopes	Frequency: 2
# Word: kilogram	Frequency: 4
# Word: radiography	Frequency: 2
# Word: radiotoxicity	Frequency: 1
# Word: americyl	Frequency: 2
# Word: amo	Frequency: 6
# Word: astatine	Frequency: 10
# Word: brookhaven	Frequency: 1
# Word: barraging	Frequency: 1
# Word: electrically	Frequency: 7
# Word: chargeless	Frequency: 1
# Word: quarks	Frequency: 6
# Word: quark	Frequency: 3
# Word: leaps	Frequency: 3
# Word: zeeman	Frequency: 1
# Word: excitations	Frequency: 1
# Word: stellar	Frequency: 9
# Word: unreactive	Frequency: 1
# Word: antimatter	Frequency: 73
# Word: antineutrons	Frequency: 1
# Word: antihydrogen	Frequency: 22
# Word: atrap	Frequency: 3
# Word: antiproton	Frequency: 16
# Word: decelerator	Frequency: 5
# Word: interstellar	Frequency: 2
# Word: jaina	Frequency: 1
# Word: katyayana	Frequency: 1
# Word: gautama	Frequency: 1
# Word: atomists	Frequency: 3
# Word: vibrate	Frequency: 1
# Word: experimentally	Frequency: 4
# Word: atomos	Frequency: 1
# Word: quantization	Frequency: 2
# Word: arare	Frequency: 1
# Word: overfarmed	Frequency: 1
# Word: aquaducts	Frequency: 1
# Word: desalination	Frequency: 2
# Word: mylar	Frequency: 1
# Word: passivation	Frequency: 1
# Word: sparking	Frequency: 1
# Word: saucepans	Frequency: 1
# Word: evaporated	Frequency: 2
# Word: spa	Frequency: 7
# Word: flakes	Frequency: 2
# Word: undercoat	Frequency: 1
# Word: anodised	Frequency: 1
# Word: transistors	Frequency: 1
# Word: weldability	Frequency: 1
# Word: technician	Frequency: 3
# Word: duplicate	Frequency: 2
# Word: misalignment	Frequency: 2
# Word: airy	Frequency: 1
# Word: vanishingly	Frequency: 1
# Word: corvair	Frequency: 1
# Word: warping	Frequency: 1
# Word: overheated	Frequency: 1
# Word: adhesives	Frequency: 1
# Word: misaligned	Frequency: 1
# Word: galvanic	Frequency: 1
# Word: pigtail	Frequency: 1
# Word: mordants	Frequency: 1
# Word: astringents	Frequency: 1
# Word: morveau	Frequency: 1
# Word: alumen	Frequency: 1
# Word: anhydrous	Frequency: 7
# Word: almanacs	Frequency: 1
# Word: piccadilly	Frequency: 1
# Word: wages	Frequency: 6
# Word: warplanes	Frequency: 1
# Word: flake	Frequency: 1
# Word: containers	Frequency: 1
# Word: cathodes	Frequency: 3
# Word: ecologically	Frequency: 1
# Word: quartz	Frequency: 8
# Word: characterisation	Frequency: 1
# Word: khanna	Frequency: 1
# Word: allergic	Frequency: 2
# Word: pans	Frequency: 1
# Word: rolaids	Frequency: 1
# Word: alzheimer	Frequency: 2
# Word: alumium	Frequency: 1
# Word: electrolytically	Frequency: 1
# Word: predominates	Frequency: 2
# Word: albr	Frequency: 1
# Word: halide	Frequency: 4
# Word: crystallization	Frequency: 1
# Word: trimethylaluminium	Frequency: 2
# Word: carbide	Frequency: 1
# Word: aln	Frequency: 1
# Word: amphoteric	Frequency: 1
# Word: alkalis	Frequency: 2
# Word: trihalides	Frequency: 1
# Word: aluminohalides	Frequency: 1
# Word: abdicatio	Frequency: 1
# Word: dicare	Frequency: 1
# Word: abdications	Frequency: 5
# Word: abdicate	Frequency: 1
# Word: endeavoured	Frequency: 1
# Word: vacant	Frequency: 1
# Word: amounted	Frequency: 4
# Word: coats	Frequency: 1
# Word: recalling	Frequency: 2
# Word: figurehead	Frequency: 5
# Word: lambeth	Frequency: 7
# Word: baptismal	Frequency: 1
# Word: baptism	Frequency: 7
# Word: organisationally	Frequency: 1
# Word: displeased	Frequency: 4
# Word: disciplinary	Frequency: 3
# Word: koinonia	Frequency: 1
# Word: lusitanian	Frequency: 1
# Word: amicable	Frequency: 1
# Word: anglicanism	Frequency: 19
# Word: langley	Frequency: 4
# Word: decennially	Frequency: 1
# Word: arne	Frequency: 1
# Word: kaijser	Frequency: 3
# Word: stadens	Frequency: 1
# Word: etableringen	Frequency: 1
# Word: rsta	Frequency: 1
# Word: framtida	Frequency: 1
# Word: utmaningar	Frequency: 1
# Word: anthologies	Frequency: 4
# Word: landform	Frequency: 1
# Word: archipelagoes	Frequency: 6
# Word: arkhi	Frequency: 2
# Word: naxos	Frequency: 1
# Word: rican	Frequency: 5
# Word: leeward	Frequency: 4
# Word: balearic	Frequency: 1
# Word: chagos	Frequency: 1
# Word: furneaux	Frequency: 1
# Word: pagos	Frequency: 1
# Word: magdalen	Frequency: 1
# Word: maluku	Frequency: 1
# Word: mindanao	Frequency: 1
# Word: sunda	Frequency: 3
# Word: farquhar	Frequency: 2
# Word: kanaky	Frequency: 1
# Word: micronesia	Frequency: 2
# Word: kiribati	Frequency: 1
# Word: ralik	Frequency: 1
# Word: ratak	Frequency: 1
# Word: novaya	Frequency: 1
# Word: gambier	Frequency: 1
# Word: navigators	Frequency: 2
# Word: haida	Frequency: 1
# Word: gwaii	Frequency: 1
# Word: severnaya	Frequency: 1
# Word: solentiname	Frequency: 1
# Word: paracel	Frequency: 1
# Word: tuscan	Frequency: 2
# Word: romances	Frequency: 4
# Word: preparatory	Frequency: 1
# Word: aston	Frequency: 1
# Word: southsea	Frequency: 2
# Word: hawkins	Frequency: 1
# Word: waterfall	Frequency: 3
# Word: crowboroughconan	Frequency: 1
# Word: mutilated	Frequency: 2
# Word: gambling	Frequency: 7
# Word: fairies	Frequency: 2
# Word: minstead	Frequency: 1
# Word: picardy	Frequency: 1
# Word: baskervilles	Frequency: 1
# Word: micah	Frequency: 3
# Word: bernac	Frequency: 1
# Word: polestar	Frequency: 1
# Word: mowbray	Frequency: 1
# Word: barthes	Frequency: 1
# Word: markov	Frequency: 17
# Word: ryazan	Frequency: 1
# Word: stochastic	Frequency: 2
# Word: andreevich	Frequency: 1
# Word: alere	Frequency: 1
# Word: alumns	Frequency: 1
# Word: matriculated	Frequency: 1
# Word: kierkegaard	Frequency: 8
# Word: existentialism	Frequency: 7
# Word: connotative	Frequency: 1
# Word: teenagers	Frequency: 3
# Word: sensations	Frequency: 1
# Word: somatic	Frequency: 2
# Word: sweating	Frequency: 3
# Word: pupillary	Frequency: 1
# Word: behaviorally	Frequency: 1
# Word: amygdala	Frequency: 3
# Word: hippocampus	Frequency: 1
# Word: zald	Frequency: 2
# Word: hagen	Frequency: 4
# Word: gorman	Frequency: 1
# Word: phobia	Frequency: 5
# Word: phobias	Frequency: 11
# Word: anticipate	Frequency: 1
# Word: margolis	Frequency: 1
# Word: antianxiety	Frequency: 1
# Word: addictive	Frequency: 14
# Word: leavitt	Frequency: 3
# Word: rowman	Frequency: 1
# Word: diaphragmic	Frequency: 1
# Word: reassuring	Frequency: 1
# Word: alcoholic	Frequency: 10
# Word: alleviation	Frequency: 1
# Word: cautioned	Frequency: 1
# Word: pharmacologically	Frequency: 1
# Word: uneasiness	Frequency: 1
# Word: correlates	Frequency: 2
# Word: olfaction	Frequency: 1
# Word: aversive	Frequency: 1
# Word: lighthearted	Frequency: 2
# Word: hartfield	Frequency: 1
# Word: facetiousness	Frequency: 1
# Word: merchandise	Frequency: 4
# Word: grahame	Frequency: 2
# Word: thwaites	Frequency: 1
# Word: readership	Frequency: 1
# Word: belinda	Frequency: 2
# Word: addicted	Frequency: 6
# Word: addict	Frequency: 8
# Word: craving	Frequency: 1
# Word: undertreated	Frequency: 1
# Word: laypersons	Frequency: 1
# Word: abatement	Frequency: 15
# Word: aforementioned	Frequency: 2
# Word: barbiturates	Frequency: 5
# Word: antidepressants	Frequency: 3
# Word: decongestants	Frequency: 1
# Word: paxil	Frequency: 1
# Word: intoxication	Frequency: 4
# Word: nida	Frequency: 2
# Word: rewarding	Frequency: 4
# Word: cannabinoids	Frequency: 1
# Word: hallucinogens	Frequency: 1
# Word: justifiable	Frequency: 4
# Word: uncontrollable	Frequency: 1
# Word: detoxification	Frequency: 1
# Word: tailor	Frequency: 1
# Word: neurochemical	Frequency: 1
# Word: assessing	Frequency: 2
# Word: alcoholism	Frequency: 7
# Word: szasz	Frequency: 8
# Word: neurobiological	Frequency: 2
# Word: attenuation	Frequency: 1
# Word: correlate	Frequency: 3
# Word: tegmental	Frequency: 1
# Word: accumbens	Frequency: 3
# Word: synapse	Frequency: 2
# Word: accumbal	Frequency: 1
# Word: homeostasis	Frequency: 1
# Word: synaptically	Frequency: 1
# Word: signalling	Frequency: 3
# Word: anhedonia	Frequency: 1
# Word: sedatives	Frequency: 2
# Word: corroborate	Frequency: 1
# Word: workaholics	Frequency: 1
# Word: narcotics	Frequency: 4
# Word: moderation	Frequency: 2
# Word: addictioninfo	Frequency: 1
# Word: axioma	Frequency: 1
# Word: axios	Frequency: 1
# Word: predicate	Frequency: 1
# Word: instantiation	Frequency: 1
# Word: forall	Frequency: 9
# Word: metaproof	Frequency: 1
# Word: metatheorems	Frequency: 1
# Word: axiomatized	Frequency: 1
# Word: commutative	Frequency: 3
# Word: specification	Frequency: 6
# Word: axiomatically	Frequency: 3
# Word: paraphernalia	Frequency: 1
# Word: galois	Frequency: 6
# Word: axiomatization	Frequency: 2
# Word: langle	Frequency: 1
# Word: sigma	Frequency: 10
# Word: geometrical	Frequency: 2
# Word: countability	Frequency: 1
# Word: alephaleph	Frequency: 1
# Word: cadmus	Frequency: 1
# Word: attribution	Frequency: 2
# Word: polarisability	Frequency: 1
# Word: alphamale	Frequency: 1
# Word: adhocracies	Frequency: 1
# Word: ersatz	Frequency: 1
# Word: proletarians	Frequency: 2
# Word: catering	Frequency: 3
# Word: straczynski	Frequency: 2
# Word: capitalize	Frequency: 2
# Word: specializing	Frequency: 1
# Word: cass	Frequency: 1
# Word: broadcaster	Frequency: 4
# Word: anguilla	Frequency: 23
# Word: iata	Frequency: 2
# Word: designator	Frequency: 1
# Word: airmail	Frequency: 1
# Word: amran	Frequency: 1
# Word: governorate	Frequency: 1
# Word: newmonians	Frequency: 1
# Word: vanishing	Frequency: 1
# Word: carib	Frequency: 1
# Word: wadadli	Frequency: 1
# Word: redonda	Frequency: 2
# Word: industrialised	Frequency: 1
# Word: patois	Frequency: 1
# Word: denomination	Frequency: 5
# Word: catherine	Frequency: 12
# Word: aragon	Frequency: 4
# Word: charlton	Frequency: 1
# Word: spiritually	Frequency: 1
# Word: agincourt	Frequency: 5
# Word: azincourt	Frequency: 1
# Word: partment	Frequency: 1
# Word: stabilised	Frequency: 1
# Word: exams	Frequency: 5
# Word: margarete	Frequency: 1
# Word: renovate	Frequency: 3
# Word: entertained	Frequency: 1
# Word: searchlights	Frequency: 1
# Word: pavilion	Frequency: 3
# Word: pavilions	Frequency: 1
# Word: welthauptstadt	Frequency: 1
# Word: germania	Frequency: 2
# Word: arno	Frequency: 3
# Word: volkshalle	Frequency: 1
# Word: carte	Frequency: 1
# Word: lazy	Frequency: 2
# Word: accompli	Frequency: 2
# Word: fanatical	Frequency: 2
# Word: assassinating	Frequency: 1
# Word: pivotal	Frequency: 1
# Word: clandestinely	Frequency: 2
# Word: suicidal	Frequency: 2
# Word: reaffirming	Frequency: 1
# Word: disfavor	Frequency: 1
# Word: faults	Frequency: 3
# Word: painstakingly	Frequency: 1
# Word: bloated	Frequency: 1
# Word: slacken	Frequency: 1
# Word: laps	Frequency: 1
# Word: visualizing	Frequency: 2
# Word: incarceration	Frequency: 2
# Word: sativum	Frequency: 2
# Word: scordoprasum	Frequency: 1
# Word: agapanthus	Frequency: 1
# Word: bessera	Frequency: 1
# Word: dandya	Frequency: 1
# Word: triteleia	Frequency: 1
# Word: gilliesia	Frequency: 1
# Word: nectaroscordum	Frequency: 1
# Word: solaria	Frequency: 1
# Word: tulbhagia	Frequency: 1
# Word: zoelnerallium	Frequency: 1
# Word: compositae	Frequency: 3
# Word: aster	Frequency: 3
# Word: daisy	Frequency: 3
# Word: magnoliophyta	Frequency: 1
# Word: synapomorphic	Frequency: 1
# Word: capitulum	Frequency: 1
# Word: anthers	Frequency: 2
# Word: torta	Frequency: 1
# Word: corollas	Frequency: 1
# Word: asteraceous	Frequency: 1
# Word: dandelions	Frequency: 2
# Word: lactuceae	Frequency: 1
# Word: cichorioideae	Frequency: 1
# Word: artichoke	Frequency: 2
# Word: guayule	Frequency: 1
# Word: hypoallergenic	Frequency: 1
# Word: centaurea	Frequency: 1
# Word: solidago	Frequency: 2
# Word: theca	Frequency: 2
# Word: corolla	Frequency: 2
# Word: hawai	Frequency: 3
# Word: carrots	Frequency: 2
# Word: caraway	Frequency: 2
# Word: anethum	Frequency: 2
# Word: graveolens	Frequency: 2
# Word: anthriscus	Frequency: 2
# Word: apium	Frequency: 2
# Word: carum	Frequency: 2
# Word: carvi	Frequency: 1
# Word: centella	Frequency: 2
# Word: daucus	Frequency: 2
# Word: vulgare	Frequency: 1
# Word: pastinaca	Frequency: 2
# Word: officinale	Frequency: 1
# Word: lovage	Frequency: 1
# Word: aciphylla	Frequency: 1
# Word: actinotus	Frequency: 1
# Word: aegopodium	Frequency: 1
# Word: ammi	Frequency: 1
# Word: ammoselinum	Frequency: 1
# Word: apiastrum	Frequency: 1
# Word: arracacia	Frequency: 1
# Word: azorella	Frequency: 1
# Word: bifora	Frequency: 1
# Word: bolax	Frequency: 1
# Word: chaerophyllum	Frequency: 1
# Word: cicuta	Frequency: 1
# Word: cynosciadium	Frequency: 1
# Word: daucosma	Frequency: 1
# Word: erigenia	Frequency: 1
# Word: ferula	Frequency: 1
# Word: glehnia	Frequency: 1
# Word: harbouria	Frequency: 1
# Word: limnosciadium	Frequency: 1
# Word: lomatium	Frequency: 1
# Word: neoparrya	Frequency: 1
# Word: orogenia	Frequency: 1
# Word: osmorhiza	Frequency: 1
# Word: perideridia	Frequency: 1
# Word: peucedanum	Frequency: 1
# Word: podistera	Frequency: 1
# Word: polytaenia	Frequency: 1
# Word: prangos	Frequency: 1
# Word: sphenosciadium	Frequency: 1
# Word: sympholoma	Frequency: 1
# Word: synelcosciadium	Frequency: 1
# Word: thapsia	Frequency: 1
# Word: thaspium	Frequency: 1
# Word: tilingia	Frequency: 1
# Word: herbarium	Frequency: 1
# Word: sheathed	Frequency: 1
# Word: schwann	Frequency: 1
# Word: insulating	Frequency: 1
# Word: myelinated	Frequency: 1
# Word: ranvier	Frequency: 1
# Word: saltation	Frequency: 1
# Word: demyelination	Frequency: 1
# Word: bifurcated	Frequency: 1
# Word: neuroglial	Frequency: 1
# Word: laminin	Frequency: 1
# Word: tenascin	Frequency: 1
# Word: perlecan	Frequency: 1
# Word: attractants	Frequency: 1
# Word: repellants	Frequency: 1
# Word: immature	Frequency: 3
# Word: patch	Frequency: 2
# Word: clamp	Frequency: 2
# Word: paleo	Frequency: 1
# Word: sogdian	Frequency: 1
# Word: forebear	Frequency: 1
# Word: rosenthal	Frequency: 1
# Word: awk	Frequency: 2
# Word: electromechanical	Frequency: 4
# Word: encyclopedias	Frequency: 2
# Word: americain	Frequency: 1
# Word: fireplace	Frequency: 1
# Word: stairs	Frequency: 2
# Word: disseminated	Frequency: 2
# Word: monophasic	Frequency: 1
# Word: autoimmune	Frequency: 1
# Word: unsteady	Frequency: 1
# Word: cerebellar	Frequency: 3
# Word: spinocerebellar	Frequency: 4
# Word: dysdiadochokinesia	Frequency: 1
# Word: alhazred	Frequency: 20
# Word: sana	Frequency: 1
# Word: azif	Frequency: 1
# Word: unpleasant	Frequency: 4
# Word: khallikan	Frequency: 2
# Word: nameless	Frequency: 4
# Word: annals	Frequency: 4
# Word: redating	Frequency: 1
# Word: laban	Frequency: 1
# Word: ehaliyeh	Frequency: 1
# Word: awliya	Frequency: 1
# Word: khali	Frequency: 1
# Word: augusta	Frequency: 22
# Word: annabella	Frequency: 5
# Word: parallelograms	Frequency: 2
# Word: menabrea	Frequency: 9
# Word: menebrea	Frequency: 1
# Word: nottingham	Frequency: 2
# Word: ambients	Frequency: 13
# Word: asynchronous	Frequency: 1
# Word: anthologist	Frequency: 1
# Word: sauk	Frequency: 3
# Word: sandra	Frequency: 2
# Word: alpes	Frequency: 3
# Word: albus	Frequency: 1
# Word: constance	Frequency: 3
# Word: bernina	Frequency: 1
# Word: periadriatic	Frequency: 1
# Word: seam	Frequency: 1
# Word: ligurian	Frequency: 1
# Word: cottian	Frequency: 1
# Word: glarus	Frequency: 2
# Word: prealps	Frequency: 1
# Word: cadibona	Frequency: 1
# Word: della	Frequency: 2
# Word: maddalena	Frequency: 1
# Word: traversed	Frequency: 1
# Word: proportionate	Frequency: 1
# Word: nappes	Frequency: 1
# Word: gigantic	Frequency: 3
# Word: matterhorn	Frequency: 1
# Word: glaciation	Frequency: 1
# Word: carolingian	Frequency: 9
# Word: saussure	Frequency: 1
# Word: placidus	Frequency: 1
# Word: spescha	Frequency: 1
# Word: alpinum	Frequency: 2
# Word: acaulis	Frequency: 2
# Word: gentian	Frequency: 1
# Word: leaved	Frequency: 1
# Word: chamorchis	Frequency: 2
# Word: alpina	Frequency: 6
# Word: glacialis	Frequency: 2
# Word: kosodrzewina	Frequency: 1
# Word: sosna	Frequency: 1
# Word: rska	Frequency: 1
# Word: pasque	Frequency: 1
# Word: androsace	Frequency: 2
# Word: jasmine	Frequency: 1
# Word: kleinwalsertal	Frequency: 1
# Word: alpenkauw	Frequency: 1
# Word: monedula	Frequency: 1
# Word: aegolius	Frequency: 1
# Word: alpinism	Frequency: 1
# Word: webcam	Frequency: 1
# Word: kam	Frequency: 2
# Word: laureate	Frequency: 47
# Word: marne	Frequency: 2
# Word: zouave	Frequency: 1
# Word: meteorological	Frequency: 1
# Word: platonisme	Frequency: 1
# Word: pca	Frequency: 2
# Word: endear	Frequency: 1
# Word: francine	Frequency: 2
# Word: pianist	Frequency: 10
# Word: leaned	Frequency: 1
# Word: absurd	Frequency: 35
# Word: clarity	Frequency: 2
# Word: existentialist	Frequency: 1
# Word: absurdist	Frequency: 3
# Word: favouring	Frequency: 1
# Word: frossard	Frequency: 1
# Word: facel	Frequency: 1
# Word: gravestone	Frequency: 1
# Word: nuptials	Frequency: 2
# Word: tranger	Frequency: 3
# Word: dualisms	Frequency: 1
# Word: dualism	Frequency: 4
# Word: unhappiness	Frequency: 2
# Word: exalts	Frequency: 1
# Word: satisfactorily	Frequency: 2
# Word: enigma	Frequency: 14
# Word: assassins	Frequency: 3
# Word: marcello	Frequency: 2
# Word: wittmann	Frequency: 1
# Word: dialoghi	Frequency: 1
# Word: literatur	Frequency: 1
# Word: italiens	Frequency: 1
# Word: frankreichs	Frequency: 1
# Word: romanistik	Frequency: 1
# Word: antiplot	Frequency: 1
# Word: existentialists	Frequency: 1
# Word: agatha	Frequency: 33
# Word: marple	Frequency: 51
# Word: dramatizations	Frequency: 1
# Word: harrogate	Frequency: 1
# Word: mallowan	Frequency: 1
# Word: wallingford	Frequency: 1
# Word: insufferable	Frequency: 1
# Word: bantry	Frequency: 3
# Word: japp	Frequency: 2
# Word: regatta	Frequency: 1
# Word: sparkling	Frequency: 3
# Word: hallowe	Frequency: 2
# Word: akhnaton	Frequency: 1
# Word: harlequin	Frequency: 1
# Word: gallop	Frequency: 2
# Word: ahoy	Frequency: 2
# Word: dames	Frequency: 1
# Word: vacationers	Frequency: 1
# Word: rambert	Frequency: 1
# Word: castel	Frequency: 2
# Word: asthma	Frequency: 4
# Word: deontological	Frequency: 2
# Word: casuistry	Frequency: 2
# Word: eichmann	Frequency: 109
# Word: obersturmbannf	Frequency: 2
# Word: wandervogel	Frequency: 2
# Word: scharf	Frequency: 2
# Word: anw	Frequency: 1
# Word: allgemeine	Frequency: 1
# Word: oberscharf	Frequency: 1
# Word: hauptscharf	Frequency: 1
# Word: feival	Frequency: 1
# Word: facilitating	Frequency: 1
# Word: reichssicherheitshauptamt	Frequency: 1
# Word: deportation	Frequency: 2
# Word: materialized	Frequency: 1
# Word: foreman	Frequency: 1
# Word: postcard	Frequency: 1
# Word: harel	Frequency: 3
# Word: kidnapping	Frequency: 4
# Word: sylvia	Frequency: 4
# Word: romantically	Frequency: 2
# Word: eichmanns	Frequency: 1
# Word: bauer	Frequency: 5
# Word: arendt	Frequency: 5
# Word: manifestly	Frequency: 1
# Word: psychopathic	Frequency: 1
# Word: standartenf	Frequency: 1
# Word: pearlman	Frequency: 1
# Word: untouchable	Frequency: 1
# Word: bormann	Frequency: 1
# Word: aquilion	Frequency: 1
# Word: westphalia	Frequency: 2
# Word: multiplicativeness	Frequency: 1
# Word: riemann	Frequency: 3
# Word: satisfies	Frequency: 10
# Word: multiplicative	Frequency: 5
# Word: ultrametric	Frequency: 1
# Word: archimedean	Frequency: 2
# Word: llabs	Frequency: 1
# Word: fabsl	Frequency: 1
# Word: nonnegative	Frequency: 1
# Word: mathworld	Frequency: 1
# Word: wolfram	Frequency: 2
# Word: weierstrass	Frequency: 1
# Word: numeration	Frequency: 1
# Word: arches	Frequency: 27
# Word: delicate	Frequency: 4
# Word: moab	Frequency: 6
# Word: redesignated	Frequency: 1
# Word: furnace	Frequency: 1
# Word: maze	Frequency: 1
# Word: navajo	Frequency: 8
# Word: circumstantial	Frequency: 2
# Word: paitue	Frequency: 1
# Word: sal	Frequency: 9
# Word: transposed	Frequency: 3
# Word: enlarging	Frequency: 2
# Word: transducer	Frequency: 1
# Word: amplifying	Frequency: 1
# Word: claythorne	Frequency: 3
# Word: wargrave	Frequency: 3
# Word: zealot	Frequency: 1
# Word: macarthur	Frequency: 2
# Word: gramophone	Frequency: 1
# Word: manners	Frequency: 4
# Word: paranoid	Frequency: 1
# Word: armostrong	Frequency: 1
# Word: sustinance	Frequency: 1
# Word: hangs	Frequency: 2
# Word: negrityat	Frequency: 2
# Word: falcone	Frequency: 1
# Word: zampino	Frequency: 1
# Word: chancery	Frequency: 1
# Word: slasher	Frequency: 2
# Word: evasion	Frequency: 1
# Word: moustache	Frequency: 1
# Word: dandified	Frequency: 1
# Word: neatness	Frequency: 1
# Word: rossakoff	Frequency: 2
# Word: sandhurst	Frequency: 1
# Word: charterhouse	Frequency: 2
# Word: meitantei	Frequency: 2
# Word: satomi	Frequency: 4
# Word: yachigusa	Frequency: 4
# Word: embarrasses	Frequency: 1
# Word: upstages	Frequency: 1
# Word: gomorrah	Frequency: 2
# Word: angela	Frequency: 3
# Word: lansbury	Frequency: 4
# Word: craddock	Frequency: 1
# Word: grafton	Frequency: 1
# Word: geriatric	Frequency: 1
# Word: goodyear	Frequency: 1
# Word: playhouse	Frequency: 1
# Word: dramatised	Frequency: 1
# Word: wanamaker	Frequency: 1
# Word: miriam	Frequency: 9
# Word: astronomically	Frequency: 3
# Word: aprilis	Frequency: 1
# Word: aphrilis	Frequency: 1
# Word: apru	Frequency: 1
# Word: aprus	Frequency: 1
# Word: saxons	Frequency: 2
# Word: symbolical	Frequency: 1
# Word: aprils	Frequency: 2
# Word: bosnian	Frequency: 2
# Word: waco	Frequency: 1
# Word: birthparents	Frequency: 1
# Word: bake	Frequency: 2
# Word: secretaries	Frequency: 2
# Word: movable	Frequency: 1
# Word: vesak	Frequency: 2
# Word: apache	Frequency: 30
# Word: mohave	Frequency: 1
# Word: songkran	Frequency: 1
# Word: paro	Frequency: 1
# Word: aufzug	Frequency: 1
# Word: pesach	Frequency: 1
# Word: passover	Frequency: 1
# Word: anniversaries	Frequency: 1
# Word: sprache	Frequency: 1
# Word: monate	Frequency: 1
# Word: lughnasadh	Frequency: 3
# Word: hatsuki	Frequency: 1
# Word: reaping	Frequency: 1
# Word: polical	Frequency: 1
# Word: vargas	Frequency: 1
# Word: aharon	Frequency: 2
# Word: tiberian	Frequency: 4
# Word: midianites	Frequency: 4
# Word: persuasive	Frequency: 1
# Word: ministerial	Frequency: 1
# Word: treasonable	Frequency: 1
# Word: amalek	Frequency: 1
# Word: clamors	Frequency: 1
# Word: unlawful	Frequency: 1
# Word: sacerdotal	Frequency: 2
# Word: fated	Frequency: 1
# Word: transaction	Frequency: 4
# Word: almonds	Frequency: 19
# Word: canaan	Frequency: 7
# Word: impatience	Frequency: 1
# Word: kadesh	Frequency: 1
# Word: mosera	Frequency: 5
# Word: itinerary	Frequency: 2
# Word: rabbinical	Frequency: 3
# Word: prophetical	Frequency: 1
# Word: sifra	Frequency: 2
# Word: pentateuch	Frequency: 1
# Word: malachi	Frequency: 3
# Word: sirach	Frequency: 10
# Word: tan	Frequency: 5
# Word: patriarchs	Frequency: 6
# Word: natan	Frequency: 1
# Word: sanhedrin	Frequency: 2
# Word: peacemaker	Frequency: 1
# Word: affliction	Frequency: 1
# Word: zeba	Frequency: 1
# Word: tabernacle	Frequency: 2
# Word: raiment	Frequency: 2
# Word: pillar	Frequency: 5
# Word: shanah	Frequency: 2
# Word: wayassa	Frequency: 1
# Word: yerushalmi	Frequency: 2
# Word: laudation	Frequency: 1
# Word: reassured	Frequency: 1
# Word: glad	Frequency: 2
# Word: canticles	Frequency: 1
# Word: gladness	Frequency: 1
# Word: anointment	Frequency: 1
# Word: spake	Frequency: 2
# Word: delineations	Frequency: 1
# Word: hexateuch	Frequency: 1
# Word: fallible	Frequency: 1
# Word: afterthought	Frequency: 1
# Word: moserah	Frequency: 1
# Word: redactional	Frequency: 1
# Word: harun	Frequency: 2
# Word: irat	Frequency: 1
# Word: gaster	Frequency: 1
# Word: jahrb	Frequency: 1
# Word: haggada	Frequency: 1
# Word: walpole	Frequency: 1
# Word: abdicates	Frequency: 2
# Word: escapes	Frequency: 1
# Word: susanna	Frequency: 1
# Word: faisal	Frequency: 1
# Word: implants	Frequency: 1
# Word: braves	Frequency: 1
# Word: babe	Frequency: 1
# Word: orphans	Frequency: 2
# Word: mecham	Frequency: 1
# Word: impeachment	Frequency: 2
# Word: netscape	Frequency: 2
# Word: sosa	Frequency: 1
# Word: muqtada	Frequency: 1
# Word: mahdi	Frequency: 1
# Word: hawza	Frequency: 1
# Word: blarer	Frequency: 1
# Word: churchman	Frequency: 1
# Word: bettina	Frequency: 1
# Word: gramme	Frequency: 1
# Word: amont	Frequency: 1
# Word: vlaminck	Frequency: 1
# Word: frances	Frequency: 3
# Word: langford	Frequency: 1
# Word: maya	Frequency: 2
# Word: angelou	Frequency: 1
# Word: inman	Frequency: 1
# Word: lugar	Frequency: 1
# Word: sharon	Frequency: 4
# Word: halpin	Frequency: 1
# Word: lahti	Frequency: 1
# Word: pollentia	Frequency: 1
# Word: reaffirm	Frequency: 1
# Word: arbroath	Frequency: 1
# Word: bessarabia	Frequency: 1
# Word: dedvukaj	Frequency: 1
# Word: mal	Frequency: 4
# Word: varney	Frequency: 2
# Word: pasco	Frequency: 1
# Word: invades	Frequency: 6
# Word: yugoslavia	Frequency: 3
# Word: massiel	Frequency: 2
# Word: newhall	Frequency: 1
# Word: habyarimana	Frequency: 2
# Word: ntaryamira	Frequency: 2
# Word: rolandas	Frequency: 1
# Word: lithuania	Frequency: 2
# Word: arvid	Frequency: 1
# Word: corsican	Frequency: 1
# Word: volkmann	Frequency: 1
# Word: moreau	Frequency: 2
# Word: hsam	Frequency: 1
# Word: veniamin	Frequency: 1
# Word: judoka	Frequency: 1
# Word: marche	Frequency: 1
# Word: albrecht	Frequency: 2
# Word: vadian	Frequency: 1
# Word: spymaster	Frequency: 1
# Word: annesley	Frequency: 1
# Word: rawlinson	Frequency: 1
# Word: arlington	Frequency: 4
# Word: stravinsky	Frequency: 2
# Word: marinus	Frequency: 1
# Word: raimundo	Frequency: 1
# Word: garson	Frequency: 2
# Word: plasmatics	Frequency: 1
# Word: bourguiba	Frequency: 2
# Word: bogoraz	Frequency: 2
# Word: rainier	Frequency: 1
# Word: monaco	Frequency: 1
# Word: anthemius	Frequency: 1
# Word: annexes	Frequency: 5
# Word: transvaal	Frequency: 6
# Word: kandersteg	Frequency: 1
# Word: brookhart	Frequency: 2
# Word: salk	Frequency: 1
# Word: imperator	Frequency: 8
# Word: yea	Frequency: 1
# Word: annihilate	Frequency: 5
# Word: gustavus	Frequency: 1
# Word: wandered	Frequency: 2
# Word: diabetics	Frequency: 1
# Word: norma	Frequency: 1
# Word: talmadge	Frequency: 1
# Word: plaines	Frequency: 1
# Word: hearns	Frequency: 1
# Word: campsite	Frequency: 1
# Word: cataldi	Frequency: 1
# Word: calvert	Frequency: 3
# Word: claudius	Frequency: 6
# Word: salmasius	Frequency: 1
# Word: fasch	Frequency: 1
# Word: leonhard	Frequency: 1
# Word: naturalist	Frequency: 8
# Word: carman	Frequency: 2
# Word: mcconachy	Frequency: 1
# Word: nikolayevich	Frequency: 1
# Word: pessa	Frequency: 1
# Word: nikolaas	Frequency: 1
# Word: bloomingdale	Frequency: 1
# Word: ansara	Frequency: 1
# Word: hazzard	Frequency: 1
# Word: dzhokhar	Frequency: 1
# Word: dudaev	Frequency: 1
# Word: kamen	Frequency: 1
# Word: pugacheva	Frequency: 1
# Word: seka	Frequency: 1
# Word: ashford	Frequency: 2
# Word: morrocan	Frequency: 1
# Word: poullain	Frequency: 1
# Word: stacey	Frequency: 1
# Word: gatti	Frequency: 1
# Word: ilya	Frequency: 3
# Word: kovalchuk	Frequency: 1
# Word: chrysoloras	Frequency: 1
# Word: zampieri	Frequency: 1
# Word: dach	Frequency: 1
# Word: waveren	Frequency: 1
# Word: aubign	Frequency: 2
# Word: marquise	Frequency: 1
# Word: argyll	Frequency: 1
# Word: bibliographer	Frequency: 3
# Word: pompadour	Frequency: 1
# Word: ignacije	Frequency: 1
# Word: rangihiwinui	Frequency: 1
# Word: peruvian	Frequency: 5
# Word: blandick	Frequency: 1
# Word: anzi	Frequency: 1
# Word: garbo	Frequency: 1
# Word: ramone	Frequency: 1
# Word: ramones	Frequency: 1
# Word: procrastinators	Frequency: 1
# Word: diena	Frequency: 1
# Word: arirang	Frequency: 1
# Word: paternus	Frequency: 2
# Word: ballparks	Frequency: 1
# Word: ziyad	Frequency: 1
# Word: ans	Frequency: 2
# Word: petar	Frequency: 1
# Word: camar	Frequency: 1
# Word: lavey	Frequency: 1
# Word: satan	Frequency: 8
# Word: haldeman	Frequency: 1
# Word: partez	Frequency: 1
# Word: airs	Frequency: 6
# Word: deranged	Frequency: 2
# Word: copeland	Frequency: 5
# Word: laval	Frequency: 2
# Word: salle	Frequency: 2
# Word: mathurin	Frequency: 1
# Word: nettlau	Frequency: 1
# Word: jaroslav	Frequency: 1
# Word: farina	Frequency: 1
# Word: clayburgh	Frequency: 1
# Word: dillard	Frequency: 1
# Word: gustaf	Frequency: 2
# Word: schollander	Frequency: 1
# Word: garner	Frequency: 5
# Word: campion	Frequency: 1
# Word: chamin	Frequency: 1
# Word: baritone	Frequency: 1
# Word: isiah	Frequency: 1
# Word: barrington	Frequency: 1
# Word: sepultura	Frequency: 1
# Word: shea	Frequency: 1
# Word: williamson	Frequency: 1
# Word: brittany	Frequency: 4
# Word: warwick	Frequency: 5
# Word: audley	Frequency: 2
# Word: marcellus	Frequency: 4
# Word: tzerclaes	Frequency: 1
# Word: eustache	Frequency: 1
# Word: fabricius	Frequency: 1
# Word: waldeck	Frequency: 1
# Word: lithographer	Frequency: 1
# Word: cartographer	Frequency: 4
# Word: douard	Frequency: 1
# Word: manet	Frequency: 2
# Word: suffragist	Frequency: 2
# Word: barkley	Frequency: 1
# Word: moorehead	Frequency: 1
# Word: balanchine	Frequency: 1
# Word: choreographer	Frequency: 6
# Word: nizar	Frequency: 1
# Word: qabbani	Frequency: 1
# Word: martyred	Frequency: 5
# Word: marianus	Frequency: 1
# Word: carranza	Frequency: 1
# Word: sardinia	Frequency: 1
# Word: sakhalin	Frequency: 1
# Word: beal	Frequency: 1
# Word: mblath	Frequency: 1
# Word: edvard	Frequency: 1
# Word: segrais	Frequency: 1
# Word: papin	Frequency: 1
# Word: maudslay	Frequency: 1
# Word: harney	Frequency: 1
# Word: saltonstall	Frequency: 1
# Word: speculator	Frequency: 1
# Word: paddick	Frequency: 1
# Word: szczepanik	Frequency: 1
# Word: bradbury	Frequency: 3
# Word: karlheinz	Frequency: 1
# Word: schwarzkopf	Frequency: 1
# Word: parcells	Frequency: 1
# Word: archies	Frequency: 1
# Word: orzabal	Frequency: 1
# Word: amos	Frequency: 4
# Word: gza	Frequency: 1
# Word: layne	Frequency: 1
# Word: staley	Frequency: 1
# Word: adewale	Frequency: 1
# Word: agbaje	Frequency: 1
# Word: backstreet	Frequency: 1
# Word: marenzio	Frequency: 1
# Word: gardie	Frequency: 1
# Word: granville	Frequency: 1
# Word: dagobert	Frequency: 1
# Word: alsatian	Frequency: 1
# Word: fragonard	Frequency: 1
# Word: lazare	Frequency: 1
# Word: neruda	Frequency: 1
# Word: gascoyne	Frequency: 1
# Word: korbinian	Frequency: 1
# Word: brodmann	Frequency: 1
# Word: gard	Frequency: 1
# Word: oliveira	Frequency: 1
# Word: cabot	Frequency: 1
# Word: ferrari	Frequency: 2
# Word: mardonius	Frequency: 1
# Word: formulary	Frequency: 1
# Word: adjudications	Frequency: 1
# Word: hatteras	Frequency: 1
# Word: krakatoa	Frequency: 1
# Word: commandos	Frequency: 1
# Word: briand	Frequency: 1
# Word: toyoda	Frequency: 1
# Word: reparation	Frequency: 1
# Word: tsurai	Frequency: 1
# Word: yamada	Frequency: 1
# Word: ira	Frequency: 2
# Word: ibrahim	Frequency: 14
# Word: babangida	Frequency: 1
# Word: estonia	Frequency: 2
# Word: yoshikazu	Frequency: 1
# Word: abensperg	Frequency: 1
# Word: hamlin	Frequency: 1
# Word: norah	Frequency: 1
# Word: bradman	Frequency: 10
# Word: kay	Frequency: 2
# Word: ramsey	Frequency: 3
# Word: nygaard	Frequency: 1
# Word: bach	Frequency: 12
# Word: stormare	Frequency: 1
# Word: lanoye	Frequency: 1
# Word: juhan	Frequency: 1
# Word: dietmar	Frequency: 1
# Word: alexa	Frequency: 1
# Word: warr	Frequency: 1
# Word: ralston	Frequency: 2
# Word: hansen	Frequency: 2
# Word: marina	Frequency: 1
# Word: erika	Frequency: 1
# Word: haile	Frequency: 2
# Word: kidnapper	Frequency: 1
# Word: poujade	Frequency: 1
# Word: volturnalia	Frequency: 1
# Word: sublimation	Frequency: 2
# Word: alkenyl	Frequency: 1
# Word: propan	Frequency: 4
# Word: methylpropan	Frequency: 2
# Word: beverages	Frequency: 4
# Word: cleanly	Frequency: 1
# Word: hangover	Frequency: 1
# Word: shakes	Frequency: 1
# Word: benzoate	Frequency: 1
# Word: yeast	Frequency: 15
# Word: propanol	Frequency: 3
# Word: geminal	Frequency: 1
# Word: alkuhul	Frequency: 1
# Word: alghwl	Frequency: 2
# Word: ghawl	Frequency: 2
# Word: headiness	Frequency: 1
# Word: pka	Frequency: 4
# Word: alkoxides	Frequency: 2
# Word: conjugated	Frequency: 2
# Word: deprotonate	Frequency: 1
# Word: activator	Frequency: 1
# Word: trimethylborane	Frequency: 1
# Word: zaitsev	Frequency: 1
# Word: catalysed	Frequency: 1
# Word: leftrightarrow	Frequency: 1
# Word: oxidants	Frequency: 1
# Word: dichromate	Frequency: 1
# Word: permanganate	Frequency: 1
# Word: periodinane	Frequency: 1
# Word: tpap	Frequency: 1
# Word: dicyano	Frequency: 1
# Word: transesterification	Frequency: 1
# Word: davitt	Frequency: 1
# Word: dooagh	Frequency: 3
# Word: crannog	Frequency: 1
# Word: dookinella	Frequency: 1
# Word: peat	Frequency: 1
# Word: granuaile	Frequency: 1
# Word: ordnace	Frequency: 1
# Word: croaghaun	Frequency: 1
# Word: gorta	Frequency: 1
# Word: pollagh	Frequency: 1
# Word: transhumance	Frequency: 2
# Word: achillbeg	Frequency: 1
# Word: beag	Frequency: 1
# Word: cashel	Frequency: 1
# Word: heyday	Frequency: 1
# Word: whitewashed	Frequency: 1
# Word: cottage	Frequency: 2
# Word: montclair	Frequency: 1
# Word: kerouac	Frequency: 3
# Word: cassady	Frequency: 2
# Word: kaufman	Frequency: 1
# Word: menace	Frequency: 1
# Word: romanticism	Frequency: 1
# Word: kagyu	Frequency: 1
# Word: mantle	Frequency: 3
# Word: clayton	Frequency: 1
# Word: gyam	Frequency: 2
# Word: naropa	Frequency: 3
# Word: chevalier	Frequency: 3
# Word: yage	Frequency: 1
# Word: breaths	Frequency: 1
# Word: swaim	Frequency: 2
# Word: realaudio	Frequency: 3
# Word: clearing	Frequency: 2
# Word: allenginsberg	Frequency: 1
# Word: waldman	Frequency: 1
# Word: waerden	Frequency: 1
# Word: bogota	Frequency: 1
# Word: gonzalo	Frequency: 1
# Word: ironclad	Frequency: 1
# Word: auburn	Frequency: 2
# Word: heligoland	Frequency: 1
# Word: bair	Frequency: 1
# Word: suvla	Frequency: 1
# Word: vitaphone	Frequency: 2
# Word: hiroshima	Frequency: 5
# Word: fallout	Frequency: 1
# Word: malebranche	Frequency: 1
# Word: wollaston	Frequency: 1
# Word: greathead	Frequency: 1
# Word: saxe	Frequency: 2
# Word: gotha	Frequency: 2
# Word: claudel	Frequency: 1
# Word: carrillo	Frequency: 1
# Word: patman	Frequency: 1
# Word: gangster	Frequency: 1
# Word: bartel	Frequency: 1
# Word: masaaki	Frequency: 1
# Word: sakai	Frequency: 1
# Word: daryl	Frequency: 1
# Word: melissa	Frequency: 2
# Word: hormisdas	Frequency: 2
# Word: ramon	Frequency: 1
# Word: naples	Frequency: 5
# Word: hathaway	Frequency: 2
# Word: bamberg	Frequency: 1
# Word: richmann	Frequency: 1
# Word: bathurst	Frequency: 2
# Word: cordwainer	Frequency: 1
# Word: adorno	Frequency: 1
# Word: transfiguration	Frequency: 1
# Word: nagashi	Frequency: 1
# Word: lantern	Frequency: 5
# Word: anatoly	Frequency: 9
# Word: karpov	Frequency: 79
# Word: anatoli	Frequency: 1
# Word: zlatoust	Frequency: 1
# Word: spassky	Frequency: 11
# Word: interzonal	Frequency: 1
# Word: incomparably	Frequency: 1
# Word: flatly	Frequency: 1
# Word: chessboard	Frequency: 1
# Word: zsuzsa	Frequency: 1
# Word: polgar	Frequency: 2
# Word: shamed	Frequency: 1
# Word: zukhar	Frequency: 1
# Word: glasses	Frequency: 2
# Word: timman	Frequency: 2
# Word: linares	Frequency: 4
# Word: stamina	Frequency: 1
# Word: gata	Frequency: 1
# Word: kamsky	Frequency: 2
# Word: scrapped	Frequency: 1
# Word: khalifman	Frequency: 1
# Word: gelfand	Frequency: 1
# Word: illescas	Frequency: 1
# Word: beliavsky	Frequency: 1
# Word: dominating	Frequency: 2
# Word: scintillating	Frequency: 1
# Word: qxa	Frequency: 2
# Word: batsford	Frequency: 1
# Word: kirsan	Frequency: 1
# Word: chessgames	Frequency: 2
# Word: chessmaniac	Frequency: 1
# Word: tatai	Frequency: 1
# Word: autosport	Frequency: 3
# Word: duryea	Frequency: 1
# Word: acf	Frequency: 1
# Word: fatalities	Frequency: 2
# Word: delage	Frequency: 1
# Word: delahaye	Frequency: 1
# Word: diametrically	Frequency: 1
# Word: aerofoil	Frequency: 1
# Word: pinnacle	Frequency: 1
# Word: kart	Frequency: 6
# Word: entrants	Frequency: 1
# Word: beforehand	Frequency: 2
# Word: aloud	Frequency: 2
# Word: elasped	Frequency: 1
# Word: differentials	Frequency: 1
# Word: supercars	Frequency: 1
# Word: nascar	Frequency: 7
# Word: raceway	Frequency: 4
# Word: specifications	Frequency: 3
# Word: featherlite	Frequency: 1
# Word: cascar	Frequency: 1
# Word: tarmac	Frequency: 1
# Word: cowdenbeath	Frequency: 2
# Word: fibreglass	Frequency: 1
# Word: dragster	Frequency: 3
# Word: nhra	Frequency: 4
# Word: sanctioning	Frequency: 2
# Word: sportsman	Frequency: 2
# Word: rallycross	Frequency: 2
# Word: bajas	Frequency: 1
# Word: karting	Frequency: 2
# Word: rainey	Frequency: 3
# Word: speedway	Frequency: 1
# Word: nascarup	Frequency: 1
# Word: stats	Frequency: 1
# Word: trackbytes	Frequency: 1
# Word: britishmotorracingsafetyfund	Frequency: 1
# Word: ihra	Frequency: 1
# Word: paddock	Frequency: 1
# Word: alms	Frequency: 2
# Word: initiatory	Frequency: 4
# Word: aggressors	Frequency: 1
# Word: pragmatic	Frequency: 3
# Word: aggress	Frequency: 2
# Word: contractual	Frequency: 5
# Word: burglary	Frequency: 3
# Word: invasive	Frequency: 4
# Word: intrinsically	Frequency: 2
# Word: regularized	Frequency: 1
# Word: appropriation	Frequency: 6
# Word: parcels	Frequency: 1
# Word: particulars	Frequency: 3
# Word: ramification	Frequency: 2
# Word: favoritism	Frequency: 2
# Word: disenfranchised	Frequency: 1
# Word: malfeasance	Frequency: 1
# Word: inalienable	Frequency: 2
# Word: generically	Frequency: 2
# Word: admire	Frequency: 2
# Word: counterargument	Frequency: 2
# Word: benchmark	Frequency: 1
# Word: gambone	Frequency: 2
# Word: jamal	Frequency: 1
# Word: plutarchy	Frequency: 1
# Word: multidimensional	Frequency: 1
# Word: bastiat	Frequency: 4
# Word: thoreau	Frequency: 5
# Word: mauvillon	Frequency: 1
# Word: faucher	Frequency: 1
# Word: dealers	Frequency: 1
# Word: weltanschauung	Frequency: 1
# Word: restraints	Frequency: 2
# Word: bankers	Frequency: 1
# Word: mutualist	Frequency: 4
# Word: anticapitalist	Frequency: 1
# Word: crocetta	Frequency: 2
# Word: althing	Frequency: 1
# Word: organically	Frequency: 2
# Word: faring	Frequency: 1
# Word: wealthier	Frequency: 2
# Word: abdullahi	Frequency: 1
# Word: manageable	Frequency: 1
# Word: rudimentary	Frequency: 4
# Word: anarchic	Frequency: 1
# Word: feudalism	Frequency: 1
# Word: nonhuman	Frequency: 1
# Word: unequal	Frequency: 2
# Word: constraint	Frequency: 1
# Word: aggregation	Frequency: 1
# Word: davidson	Frequency: 3
# Word: kinsella	Frequency: 1
# Word: panarchy	Frequency: 1
# Word: liberalia	Frequency: 1
# Word: samizdata	Frequency: 1
# Word: dahiya	Frequency: 1
# Word: intellecutal	Frequency: 1
# Word: somalianarchy	Frequency: 1
# Word: anarco	Frequency: 1
# Word: capitalismo	Frequency: 1
# Word: khanate	Frequency: 1
# Word: ashburton	Frequency: 1
# Word: mohandas	Frequency: 3
# Word: bombay	Frequency: 5
# Word: headington	Frequency: 1
# Word: kaifu	Frequency: 1
# Word: enacts	Frequency: 1
# Word: sbarro	Frequency: 1
# Word: thedmar	Frequency: 1
# Word: maxmili	Frequency: 1
# Word: avogadro	Frequency: 1
# Word: andreyev	Frequency: 1
# Word: jansson	Frequency: 1
# Word: romano	Frequency: 2
# Word: kellerman	Frequency: 1
# Word: hata	Frequency: 1
# Word: sanders	Frequency: 1
# Word: gillian	Frequency: 1
# Word: bana	Frequency: 2
# Word: percival	Frequency: 1
# Word: inzaghi	Frequency: 1
# Word: mitra	Frequency: 1
# Word: holdsclaw	Frequency: 1
# Word: mikael	Frequency: 1
# Word: audrey	Frequency: 2
# Word: tautou	Frequency: 1
# Word: horikawa	Frequency: 2
# Word: cajetan	Frequency: 1
# Word: orientalist	Frequency: 1
# Word: leoncavallo	Frequency: 1
# Word: benedicta	Frequency: 1
# Word: tate	Frequency: 1
# Word: shostakovich	Frequency: 1
# Word: harsanyi	Frequency: 1
# Word: harford	Frequency: 1
# Word: ostiarius	Frequency: 1
# Word: attic	Frequency: 1
# Word: parabasis	Frequency: 2
# Word: satirizes	Frequency: 1
# Word: lysistrata	Frequency: 2
# Word: comical	Frequency: 1
# Word: thesmophoriazusae	Frequency: 2
# Word: proagon	Frequency: 1
# Word: gerytades	Frequency: 1
# Word: anagyros	Frequency: 1
# Word: agathon	Frequency: 1
# Word: heintzelman	Frequency: 1
# Word: kaysersberg	Frequency: 1
# Word: eschatological	Frequency: 6
# Word: apostle	Frequency: 12
# Word: organist	Frequency: 2
# Word: assisi	Frequency: 1
# Word: defeatism	Frequency: 1
# Word: primeval	Frequency: 3
# Word: edgar	Frequency: 8
# Word: leavening	Frequency: 1
# Word: chinua	Frequency: 1
# Word: lambar	Frequency: 9
# Word: garaison	Frequency: 1
# Word: pastor	Frequency: 8
# Word: lazarus	Frequency: 1
# ...
# Word: arta	Frequency: 1
# Word: pendants	Frequency: 1
# Word: mineralized	Frequency: 1
# Word: kahroba	Frequency: 1
# Word: hashmal	Frequency: 1
# Word: tacitus	Frequency: 1
# Word: breakers	Frequency: 1
# Word: labdanes	Frequency: 1
# Word: tetrameric	Frequency: 1
# Word: matures	Frequency: 1
# Word: isomerization	Frequency: 1
# Word: cyclization	Frequency: 1
# Word: glauconitic	Frequency: 1
# Word: kaliningrad	Frequency: 2
# Word: succinifera	Frequency: 1
# Word: antennae	Frequency: 2
# Word: crustaceans	Frequency: 2
# Word: receptacles	Frequency: 1
# Word: haff	Frequency: 1
# Word: stantien	Frequency: 1
# Word: inasmuch	Frequency: 1
# Word: lathe	Frequency: 2
# Word: smearing	Frequency: 1
# Word: ambroid	Frequency: 1
# Word: aldeburgh	Frequency: 1
# Word: naze	Frequency: 1
# Word: olbia	Frequency: 1
# Word: massilia	Frequency: 1
# Word: hatria	Frequency: 2
# Word: hymenea	Frequency: 1
# Word: gedanum	Frequency: 1
# Word: gutta	Frequency: 1
# Word: krantzite	Frequency: 1
# Word: giaretta	Frequency: 1
# Word: catania	Frequency: 1
# Word: mandalay	Frequency: 1
# Word: coals	Frequency: 1
# Word: chemawinite	Frequency: 1
# Word: cedarite	Frequency: 1
# Word: richa	Frequency: 1
# Word: arkivoc	Frequency: 1
# Word: emporia	Frequency: 2
# Word: gdansk	Frequency: 1
# Word: gesalec	Frequency: 2
# Word: septimania	Frequency: 1
# Word: chrotilda	Frequency: 1
# Word: konami	Frequency: 1
# Word: castlevania	Frequency: 3
# Word: fearsome	Frequency: 1
# Word: alphorn	Frequency: 12
# Word: alpenhorn	Frequency: 6
# Word: harmonics	Frequency: 1
# Word: vaches	Frequency: 1
# Word: brahms	Frequency: 1
# Word: oberland	Frequency: 1
# Word: sinfonia	Frequency: 1
# Word: daetwyler	Frequency: 1
# Word: jacaranda	Frequency: 1
# Word: alphorns	Frequency: 1
# Word: artiodactyla	Frequency: 1
# Word: mohair	Frequency: 3
# Word: alpace	Frequency: 1
# Word: fawns	Frequency: 1
# Word: baa	Frequency: 1
# Word: wark	Frequency: 1
# Word: paddocks	Frequency: 1
# Word: crias	Frequency: 1
# Word: cria	Frequency: 1
# Word: lama	Frequency: 1
# Word: shear	Frequency: 2
# Word: greetland	Frequency: 1
# Word: acclimatize	Frequency: 1
# Word: peacetime	Frequency: 1
# Word: bioinformatics	Frequency: 1
# Word: caimans	Frequency: 3
# Word: gharial	Frequency: 1
# Word: jagged	Frequency: 1
# Word: fluvial	Frequency: 1
# Word: lagarto	Frequency: 1
# Word: paleosuchus	Frequency: 4
# Word: melanosuchus	Frequency: 5
# Word: spectacled	Frequency: 2
# Word: jacare	Frequency: 1
# Word: diplocynodontinae	Frequency: 1
# Word: baryphracta	Frequency: 1
# Word: akantosuchus	Frequency: 1
# Word: albertochampsa	Frequency: 1
# Word: hassiacosuchus	Frequency: 1
# Word: navahosuchus	Frequency: 1
# Word: allognathosuchus	Frequency: 1
# Word: arambourgia	Frequency: 1
# Word: wannaganosuchus	Frequency: 1
# Word: prenasalis	Frequency: 1
# Word: caimaninae	Frequency: 1
# Word: eocaiman	Frequency: 1
# Word: palpebrosus	Frequency: 1
# Word: trigonatus	Frequency: 1
# Word: yacare	Frequency: 2
# Word: apaporiensis	Frequency: 1
# Word: lutescans	Frequency: 1
# Word: latirostris	Frequency: 1
# Word: aliat	Frequency: 1
# Word: kamchatka	Frequency: 2
# Word: andreanof	Frequency: 1
# Word: habitable	Frequency: 1
# Word: unalaska	Frequency: 11
# Word: herbage	Frequency: 1
# Word: practicable	Frequency: 1
# Word: stalks	Frequency: 1
# Word: unangan	Frequency: 1
# Word: interglacial	Frequency: 2
# Word: komandorski	Frequency: 1
# Word: adak	Frequency: 1
# Word: veniaminov	Frequency: 1
# Word: ancsa	Frequency: 1
# Word: ounalashka	Frequency: 1
# Word: aleutianislands	Frequency: 1
# Word: sialidae	Frequency: 1
# Word: branchial	Frequency: 1
# Word: pupal	Frequency: 1
# Word: sialis	Frequency: 2
# Word: chauliodes	Frequency: 1
# Word: megaloptera	Frequency: 1
# Word: alnus	Frequency: 9
# Word: betulaceae	Frequency: 1
# Word: formosana	Frequency: 1
# Word: alders	Frequency: 4
# Word: lepidoptera	Frequency: 2
# Word: fagales	Frequency: 1
# Word: alcox	Frequency: 1
# Word: alcocke	Frequency: 1
# Word: garrisonian	Frequency: 1
# Word: pecuniarily	Frequency: 1
# Word: wayside	Frequency: 2
# Word: transcendentalists	Frequency: 2
# Word: louisa	Frequency: 1
# Word: transcendentalist	Frequency: 1
# Word: procellarids	Frequency: 3
# Word: diomedea	Frequency: 9
# Word: mollymawks	Frequency: 7
# Word: phoebetria	Frequency: 5
# Word: ahlquist	Frequency: 2
# Word: ornithological	Frequency: 1
# Word: rhothonia	Frequency: 1
# Word: julietata	Frequency: 1
# Word: laysanornis	Frequency: 1
# Word: penthirenia	Frequency: 1
# Word: tailed	Frequency: 4
# Word: cambered	Frequency: 1
# Word: gradient	Frequency: 1
# Word: anticlockwise	Frequency: 1
# Word: forager	Frequency: 1
# Word: patchily	Frequency: 1
# Word: vagrants	Frequency: 1
# Word: gannet	Frequency: 1
# Word: cephalopods	Frequency: 1
# Word: dataloggers	Frequency: 1
# Word: scavenged	Frequency: 1
# Word: otago	Frequency: 2
# Word: dances	Frequency: 3
# Word: frigatebird	Frequency: 1
# Word: mollymawk	Frequency: 1
# Word: fulmar	Frequency: 1
# Word: overgrazed	Frequency: 1
# Word: flotsam	Frequency: 1
# Word: amsterdamensis	Frequency: 1
# Word: sanfordi	Frequency: 1
# Word: epomophora	Frequency: 1
# Word: albatrus	Frequency: 1
# Word: melanophris	Frequency: 2
# Word: impavida	Frequency: 1
# Word: eremita	Frequency: 1
# Word: chrysostoma	Frequency: 1
# Word: carteri	Frequency: 1
# Word: fusca	Frequency: 1
# Word: hanzab	Frequency: 1
# Word: acap	Frequency: 1
# Word: arachnophobics	Frequency: 2
# Word: traumatizing	Frequency: 1
# Word: wherabouts	Frequency: 1
# Word: psychoanal	Frequency: 1
# Word: calcite	Frequency: 6
# Word: alabastrites	Frequency: 1
# Word: soane	Frequency: 2
# Word: panes	Frequency: 1
# Word: stalagmitic	Frequency: 1
# Word: banded	Frequency: 1
# Word: assiut	Frequency: 1
# Word: tehuac	Frequency: 1
# Word: brak	Frequency: 1
# Word: marls	Frequency: 2
# Word: chellaston	Frequency: 2
# Word: fauld	Frequency: 1
# Word: staffordshire	Frequency: 1
# Word: watchet	Frequency: 1
# Word: spheroidal	Frequency: 1
# Word: fluorspar	Frequency: 1
# Word: staircases	Frequency: 1
# Word: calcination	Frequency: 1
# Word: agatiform	Frequency: 1
# Word: castellina	Frequency: 2
# Word: marmo	Frequency: 1
# Word: sulphate	Frequency: 1
# Word: pigmentary	Frequency: 1
# Word: samaria	Frequency: 4
# Word: melkart	Frequency: 1
# Word: tyrian	Frequency: 1
# Word: baal	Frequency: 1
# Word: elijah	Frequency: 3
# Word: karkar	Frequency: 1
# Word: apamea	Frequency: 1
# Word: baasha	Frequency: 1
# Word: hadad	Frequency: 2
# Word: aphek	Frequency: 1
# Word: ramoth	Frequency: 1
# Word: ahaziah	Frequency: 1
# Word: jehoram	Frequency: 2
# Word: monomanical	Frequency: 1
# Word: asic	Frequency: 2
# Word: dasyprocta	Frequency: 12
# Word: agouti	Frequency: 18
# Word: coiban	Frequency: 1
# Word: coibae	Frequency: 1
# Word: kalinowski	Frequency: 1
# Word: leporina	Frequency: 1
# Word: ruatanica	Frequency: 1
# Word: myoprocta	Frequency: 3
# Word: acouchi	Frequency: 2
# Word: pratti	Frequency: 1
# Word: acouchy	Frequency: 1
# Word: paca	Frequency: 3
# Word: taczanowskii	Frequency: 1
# Word: agoutidae	Frequency: 1
# Word: montanari	Frequency: 1
# Word: subgiant	Frequency: 2
# Word: cratering	Frequency: 1
# Word: kabbalistic	Frequency: 1
# Word: mainstars	Frequency: 1
# Word: kaler	Frequency: 1
# Word: pentatonic	Frequency: 1
# Word: bagpipe	Frequency: 1
# Word: folkways	Frequency: 1
# Word: weavers	Frequency: 1
# Word: sav	Frequency: 1
# Word: arlo	Frequency: 2
# Word: hayley	Frequency: 1
# Word: rerelease	Frequency: 1
# Word: easybyte	Frequency: 1
# Word: recrimination	Frequency: 1
# Word: comcast	Frequency: 1
# Word: gameline	Frequency: 2
# Word: caufield	Frequency: 1
# Word: applelink	Frequency: 1
# Word: chatroom	Frequency: 2
# Word: caribe	Frequency: 1
# Word: bayou	Frequency: 1
# Word: userbase	Frequency: 1
# Word: leveraging	Frequency: 1
# Word: environmentalists	Frequency: 1
# Word: biodegradable	Frequency: 1
# Word: aolers	Frequency: 1
# Word: imap	Frequency: 1
# Word: rainman	Frequency: 1
# Word: catwatch	Frequency: 1
# Word: cancel	Frequency: 3
# Word: naviserver	Frequency: 1
# Word: relaunch	Frequency: 1
# Word: ax	Frequency: 1
# Word: coalgebra	Frequency: 1
# Word: bakhshali	Frequency: 1
# Word: arithmetica	Frequency: 1
# Word: brahmagupta	Frequency: 1
# Word: ziauddin	Frequency: 1
# Word: ravetz	Frequency: 1
# Word: exampleproblems	Frequency: 1
# Word: nazareth	Frequency: 1
# Word: nostrae	Frequency: 1
# Word: reparatae	Frequency: 1
# Word: regnal	Frequency: 7
# Word: consulares	Frequency: 1
# Word: tribunican	Frequency: 1
# Word: deposals	Frequency: 1
# Word: judaeo	Frequency: 1
# Word: tonnenna	Frequency: 1
# Word: annunciation	Frequency: 1
# Word: alcuin	Frequency: 17
# Word: miaire	Frequency: 1
# Word: chulalongkorn	Frequency: 1
# Word: hijra	Frequency: 1
# Word: sacris	Frequency: 1
# Word: vernal	Frequency: 3
# Word: digram	Frequency: 1
# Word: avianca	Frequency: 1
# Word: attovolt	Frequency: 1
# Word: covalently	Frequency: 1
# Word: rabanus	Frequency: 1
# Word: maurus	Frequency: 1
# Word: otgar	Frequency: 1
# Word: mainz	Frequency: 1
# Word: ealhwine	Frequency: 1
# Word: headship	Frequency: 1
# Word: pallium	Frequency: 1
# Word: parma	Frequency: 1
# Word: adoptionist	Frequency: 1
# Word: asturias	Frequency: 1
# Word: adoptionism	Frequency: 1
# Word: preponderant	Frequency: 1
# Word: patribus	Frequency: 1
# Word: sanctis	Frequency: 1
# Word: ecclesiae	Frequency: 1
# Word: iconoclasm	Frequency: 1
# Word: nithard	Frequency: 1
# Word: einhard	Frequency: 1
# Word: traube	Frequency: 1
# Word: diamine	Frequency: 1
# Word: tetraamine	Frequency: 1
# Word: aminoethanol	Frequency: 1
# Word: electronegative	Frequency: 1
# Word: acetone	Frequency: 1
# Word: chirality	Frequency: 1
# Word: optically	Frequency: 1
# Word: elevating	Frequency: 1
# Word: delocalise	Frequency: 1
# Word: protonation	Frequency: 1
# Word: azides	Frequency: 1
# Word: staudinger	Frequency: 1
# Word: allylic	Frequency: 1
# Word: baylis	Frequency: 1
# Word: uncontaminated	Frequency: 1
# Word: alkylaton	Frequency: 1
# Word: pseudohalide	Frequency: 1
# Word: acylated	Frequency: 1
# Word: acylation	Frequency: 1
# Word: diazonium	Frequency: 7
# Word: carbonium	Frequency: 2
# Word: phenylamine	Frequency: 1
# Word: ponceau	Frequency: 1
# Word: antihistamine	Frequency: 1
# Word: chlorpromazine	Frequency: 1
# Word: tranquilliser	Frequency: 1
# Word: paracetamol	Frequency: 1
# Word: acetaminophenol	Frequency: 1
# Word: analgesic	Frequency: 1
# Word: ashmun	Frequency: 1
# Word: sargent	Frequency: 2
# Word: acquittal	Frequency: 1
# Word: arbuthnot	Frequency: 1
# Word: ancaster	Frequency: 1
# Word: jourdan	Frequency: 1
# Word: boulanger	Frequency: 1
# Word: zauditu	Frequency: 1
# Word: werkman	Frequency: 1
# Word: bandleader	Frequency: 1
# Word: aparicio	Frequency: 1
# Word: mehta	Frequency: 1
# Word: dibnah	Frequency: 1
# Word: galina	Frequency: 1
# Word: tammi	Frequency: 1
# Word: olavo	Frequency: 1
# Word: nora	Frequency: 1
# Word: skateboarder	Frequency: 1
# Word: kian	Frequency: 1
# Word: talmudist	Frequency: 1
# Word: poda	Frequency: 1
# Word: taira	Frequency: 2
# Word: antoku	Frequency: 1
# Word: castilians	Frequency: 1
# Word: aljubarrota	Frequency: 1
# Word: zelaya	Frequency: 1
# Word: tuvinian	Frequency: 1
# Word: tillamook	Frequency: 1
# Word: blackout	Frequency: 1
# Word: casaubon	Frequency: 1
# Word: castelnuovo	Frequency: 1
# Word: aleksandar	Frequency: 1
# Word: maharishi	Frequency: 1
# Word: lina	Frequency: 1
# Word: fargas	Frequency: 1
# Word: danielle	Frequency: 1
# Word: backlund	Frequency: 1
# Word: larson	Frequency: 1
# Word: marcia	Frequency: 1
# Word: earvin	Frequency: 1
# Word: halle	Frequency: 1
# Word: okocha	Frequency: 1
# Word: elena	Frequency: 1
# Word: baltacha	Frequency: 1
# Word: gymnast	Frequency: 1
# Word: dassel	Frequency: 1
# Word: fitzalan	Frequency: 1
# Word: arundel	Frequency: 1
# Word: tatsuoki	Frequency: 1
# Word: talbot	Frequency: 1
# Word: sabatier	Frequency: 1
# Word: sondergaard	Frequency: 1
# Word: eddahab	Frequency: 1
# Word: polyatomic	Frequency: 1
# Word: equipartition	Frequency: 1
# Word: adiabats	Frequency: 11
# Word: callen	Frequency: 2
# Word: unanticipated	Frequency: 1
# Word: rankine	Frequency: 1
# Word: astute	Frequency: 1
# Word: leanhardt	Frequency: 1
# Word: lapse	Frequency: 2
# Word: approximates	Frequency: 2
# Word: noticably	Frequency: 1
# Word: quantified	Frequency: 1
# Word: thousandths	Frequency: 1
# Word: exponentiate	Frequency: 1
# Word: concave	Frequency: 2
# Word: severally	Frequency: 1
# Word: entropyandtemp	Frequency: 1
# Word: isobaric	Frequency: 1
# Word: quasistatic	Frequency: 1
# Word: azanides	Frequency: 1
# Word: kevlar	Frequency: 1
# Word: haack	Frequency: 1
# Word: linkage	Frequency: 1
# Word: kinetically	Frequency: 1
# Word: dimethylpropanamide	Frequency: 1
# Word: acrylamide	Frequency: 1
# Word: animate	Frequency: 2
# Word: wards	Frequency: 1
# Word: malignant	Frequency: 2
# Word: headhunters	Frequency: 1
# Word: transmigrates	Frequency: 1
# Word: basutus	Frequency: 1
# Word: wilyamarraba	Frequency: 1
# Word: autohypnotic	Frequency: 1
# Word: trance	Frequency: 3
# Word: shaman	Frequency: 1
# Word: veridical	Frequency: 1
# Word: astral	Frequency: 1
# Word: phantasmic	Frequency: 1
# Word: dualistic	Frequency: 1
# Word: incorporeal	Frequency: 1
# Word: impalpable	Frequency: 1
# Word: anthropomorphization	Frequency: 1
# Word: satyrs	Frequency: 1
# Word: thenceforward	Frequency: 1
# Word: abodes	Frequency: 3
# Word: inanimate	Frequency: 1
# Word: nias	Frequency: 1
# Word: dakotas	Frequency: 1
# Word: ferryman	Frequency: 1
# Word: wreak	Frequency: 1
# Word: pontianak	Frequency: 1
# Word: separable	Frequency: 1
# Word: banish	Frequency: 1
# Word: spiritualized	Frequency: 1
# Word: pari	Frequency: 1
# Word: passu	Frequency: 1
# Word: scholastics	Frequency: 1
# Word: stahl	Frequency: 1
# Word: heathens	Frequency: 1
# Word: marrett	Frequency: 1
# Word: hallowell	Frequency: 4
# Word: lifeway	Frequency: 1
# Word: ojibwa	Frequency: 2
# Word: preferable	Frequency: 1
# Word: vandino	Frequency: 1
# Word: barber	Frequency: 1
# Word: dispensation	Frequency: 1
# Word: maestro	Frequency: 2
# Word: rehearse	Frequency: 1
# Word: giraud	Frequency: 1
# Word: paltry	Frequency: 1
# Word: adored	Frequency: 1
# Word: cetra	Frequency: 2
# Word: pauper	Frequency: 1
# Word: rooseveltsplatz	Frequency: 1
# Word: galuppi	Frequency: 1
# Word: fanna	Frequency: 1
# Word: emagine	Frequency: 1
# Word: tomatis	Frequency: 1
# Word: sinfonias	Frequency: 1
# Word: oratorio	Frequency: 2
# Word: triumphans	Frequency: 2
# Word: beatus	Frequency: 2
# Word: magnificat	Frequency: 3
# Word: stagioni	Frequency: 2
# Word: dramatize	Frequency: 1
# Word: viela	Frequency: 1
# Word: pazzo	Frequency: 1
# Word: rosilena	Frequency: 1
# Word: olimpiade	Frequency: 1
# Word: tamerlano	Frequency: 1
# Word: griselda	Frequency: 1
# Word: catone	Frequency: 1
# Word: utica	Frequency: 1
# Word: mandolin	Frequency: 1
# Word: sopranino	Frequency: 3
# Word: laetatus	Frequency: 1
# Word: galante	Frequency: 1
# Word: lamo	Frequency: 1
# Word: aar	Frequency: 5
# Word: hasli	Frequency: 1
# Word: handegg	Frequency: 1
# Word: guttannen	Frequency: 1
# Word: swampy	Frequency: 1
# Word: interlaken	Frequency: 1
# Word: kander	Frequency: 2
# Word: saane	Frequency: 2
# Word: nears	Frequency: 1
# Word: hagneck	Frequency: 1
# Word: nidau	Frequency: 1
# Word: gravels	Frequency: 1
# Word: aarburg	Frequency: 1
# Word: hallwiler	Frequency: 1
# Word: allenbach	Frequency: 1
# Word: canyons	Frequency: 1
# Word: agbar	Frequency: 1
# Word: edessa	Frequency: 1
# Word: abgarus	Frequency: 1
# Word: thaddeus	Frequency: 1
# Word: osrhoeans	Frequency: 1
# Word: cartleyhole	Frequency: 1
# Word: clarty	Frequency: 1
# Word: parallelogram	Frequency: 1
# Word: baronial	Frequency: 1
# Word: lockhart	Frequency: 1
# Word: granddaughter	Frequency: 1
# Word: maitland	Frequency: 1
# Word: baha	Frequency: 1
# Word: lahire	Frequency: 1
# Word: maimonides	Frequency: 1
# Word: khaldis	Frequency: 2
# Word: kutha	Frequency: 1
# Word: sarai	Frequency: 9
# Word: haran	Frequency: 10
# Word: forefathers	Frequency: 1
# Word: nahor	Frequency: 1
# Word: theophany	Frequency: 1
# Word: gerar	Frequency: 1
# Word: abimelech	Frequency: 1
# Word: heareth	Frequency: 1
# Word: moriah	Frequency: 1
# Word: sheba	Frequency: 2
# Word: machpelah	Frequency: 1
# Word: begat	Frequency: 1
# Word: unscathed	Frequency: 1
# Word: figurative	Frequency: 1
# Word: ismail	Frequency: 10
# Word: dua	Frequency: 1
# Word: salat	Frequency: 1
# Word: teased	Frequency: 1
# Word: jumrah	Frequency: 1
# Word: adha	Frequency: 1
# Word: brahma	Frequency: 3
# Word: saraisvati	Frequency: 2
# Word: nebaioth	Frequency: 1
# Word: midian	Frequency: 2
# Word: genealogies	Frequency: 1
# Word: havilah	Frequency: 1
# Word: amorites	Frequency: 2
# Word: ellasar	Frequency: 1
# Word: larsa	Frequency: 1
# Word: lagamer	Frequency: 1
# Word: gazza	Frequency: 1
# Word: tudhaliya	Frequency: 1
# Word: mimimalists	Frequency: 1
# Word: bradshaw	Frequency: 1
# Word: engraved	Frequency: 2
# Word: amulets	Frequency: 1
# Word: anguipede	Frequency: 1
# Word: cabalistic	Frequency: 1

# %% [markdown]
# **(2) DataFrame Task: Create a Spark dataframe using the iris json data men-
# tioned above. Calculate Pearson Correlation between the columns petal-
# Length and petalWidth using the appropriate dataframe API. Show the
# columns sepalLength, sepalWidth and species for the rows of data that has
# petalLength greater than or equal to 1.4 using the appropriate dataframe
# API.**

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("Iris DataFrame Task") \
    .getOrCreate()

# Read the iris JSON data into a DataFrame
iris_df = spark.read.json("/content/iris.json")

# Calculate Pearson Correlation between petalLength and petalWidth
correlation = iris_df.stat.corr("petalLength", "petalWidth")

print("Pearson Correlation between petalLength and petalWidth:", correlation)

# Show columns sepalLength, sepalWidth, and species for rows where petalLength >= 1.4
filtered_df = iris_df.filter(iris_df["petalLength"] >= 1.4).select("sepalLength", "sepalWidth", "species")
filtered_df.show()

# Stop the SparkSession
spark.stop()
# Out:
# Pearson Correlation between petalLength and petalWidth: 0.9626417223780231
# +-----------+----------+-------+
# |sepalLength|sepalWidth|species|
# +-----------+----------+-------+
# |        5.1|       3.5| setosa|
# |        4.9|       3.0| setosa|
# |        4.6|       3.1| setosa|
# |        5.0|       3.6| setosa|
# |        5.4|       3.9| setosa|
# |        4.6|       3.4| setosa|
# |        5.0|       3.4| setosa|
# |        4.4|       2.9| setosa|
# |        4.9|       3.1| setosa|
# |        5.4|       3.7| setosa|
# |        4.8|       3.4| setosa|
# |        4.8|       3.0| setosa|
# |        5.7|       4.4| setosa|
# |        5.1|       3.5| setosa|
# |        5.7|       3.8| setosa|
# |        5.1|       3.8| setosa|
# |        5.4|       3.4| setosa|
# |        5.1|       3.7| setosa|
# |        5.1|       3.3| setosa|
# |        4.8|       3.4| setosa|
# +-----------+----------+-------+
# only showing top 20 rows
